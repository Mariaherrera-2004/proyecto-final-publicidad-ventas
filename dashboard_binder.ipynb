# %% [markdown]
# # Dashboard — Publicidad digital y ventas en e-commerce
#
# Este notebook lanza `app.py` (la aplicación Dash) como proceso en segundo plano y expone el enlace para verla dentro de Binder, usando `jupyter-server-proxy` (ya incluido en `requirements.txt`).
#
# **Pasos:** Cell → Run All. Espere ~5 segundos y haga clic en el enlace que aparece debajo de la segunda celda.

# %%
import subprocess, time, os

# Lanza la app Dash en segundo plano en el puerto 8050
proceso = subprocess.Popen(["python", "app.py"], cwd=os.getcwd())
time.sleep(5)
print("Dashboard iniciado en segundo plano (PID:", proceso.pid, ")")

# %%
from IPython.display import HTML

# jupyter-server-proxy expone cualquier puerto local bajo /proxy/<puerto>/
HTML('<a href="../proxy/8050/" target="_blank" '
     'style="font-size:1.1em;">Abrir el dashboard interactivo</a>')

# %% [markdown]
# Si el enlace no funciona de inmediato, espere unos segundos y vuelva a intentarlo (la app puede tardar un momento en levantar el servidor).
